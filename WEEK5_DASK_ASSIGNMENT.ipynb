# %% [raw]
# Nandini Gudala
# HDS 5230 - High Performance Computing
# Week 5 Dask Programming Assignment

# %%
import dask.dataframe as dd
import pandas as pd

# %%
dtype_dict = {
    'population': 'float64', 
    'cases': 'float64', 
    'deaths': 'float64', 
    'aggregate': 'object', 
    'city': 'object'
}

df = dd.read_csv("timeseries.csv", dtype=dtype_dict, low_memory=False)

# Filtering the data for US states
us_states_df = df[(df['country'] == 'United States') & (df['state'].notnull())]

# Converting the  date column to datetime format
us_states_df['date'] = dd.to_datetime(us_states_df['date'])

# Filtering for the required date range
filtered_df = us_states_df[(us_states_df['date'] >= "2020-01-01") & (us_states_df['date'] <= "2021-02-28")]

# Compute total deaths per state in the period
deaths_per_state = filtered_df.groupby('state')['deaths'].sum().compute()

# Compute average population per state in the period
avg_population_per_state = filtered_df.groupby('state')['population'].mean().compute()

# Compute per-capita mortality
per_capita_mortality = (deaths_per_state / avg_population_per_state).sort_values(ascending=False)
per_capita_mortality
# Out:
# state
# New York                        6.395701
# Michigan                        3.204753
# Louisiana                       2.735288
# Illinois                        2.043863
# New Jersey                      2.031200
# Georgia                         2.026085
# Pennsylvania                    1.831572
# Virginia                        1.359063
# Mississippi                     1.356705
# Indiana                         1.353423
# Ohio                            1.058943
# Iowa                            0.958771
# Massachusetts                   0.904775
# Colorado                        0.894296
# Minnesota                       0.768853
# Kentucky                        0.751512
# Texas                           0.737643
# Missouri                        0.711146
# Connecticut                     0.677952
# Maryland                        0.658347
# Alabama                         0.599759
# North Carolina                  0.549190
# Florida                         0.545793
# ...

# %%
#calculating  (CFR)
filtered_df['month'] = filtered_df['date'].dt.to_period("M")
cfr_per_month = filtered_df.groupby(['state', 'month']).apply(lambda x: (x['deaths'].sum() / x['cases'].sum()) * 100, meta=('x', 'f8')).compute()
cfr_per_month = cfr_per_month.fillna(0).unstack(level=-1)  # Fill NaN with 0
print(cfr_per_month)
# Out:
# month                         2020-01   2020-02   2020-03    2020-04  \
# state
# Alabama                           NaN       NaN  0.532313   2.830899
# Alaska                            NaN       NaN  0.335008   2.314519
# American Samoa                    NaN       NaN       NaN   0.000000
# Arizona                           0.0  0.000000  0.000000   1.486545
# Arkansas                          NaN       NaN  0.915656   1.911450
# California                        0.0  0.000000  2.006735   3.479974
# Colorado                          NaN       NaN  0.939250   2.636616
# Connecticut                       NaN       NaN  1.814771   6.477626
# Delaware                          NaN       NaN  1.334107   2.734038
# Florida                           NaN       NaN  0.842669   2.905738
# Georgia                           NaN       NaN  2.185574   3.980977
# Guam                              NaN       NaN  2.702703   3.615483
# ...

# %%
# Calculating CFR change over time
cfr_change = cfr_per_month.diff(axis=1).sum(axis=1).sort_values(ascending=False)
print(cfr_change)
# Out:
# state
# Connecticut                     9.500807
# Michigan                        8.623360
# New Jersey                      8.251406
# Massachusetts                   7.437951
# Pennsylvania                    7.418973
# New York                        7.233961
# Northern Mariana Islands        6.535948
# New Hampshire                   6.436738
# United States Virgin Islands    5.976096
# Rhode Island                    5.821287
# Washington, D.C.                5.330110
# Indiana                         5.314359
# Ohio                            5.275945
# Louisiana                       5.138853
# Colorado                        5.063691
# Illinois                        4.802791
# Maryland                        4.649307
# Vermont                         4.559147
# Delaware                        4.013148
# New Mexico                      4.003795
# Missouri                        3.979086
# Minnesota                       3.958075
# Washington                      3.921734
# ...

# %% [raw]
# #The utilization of parallel processing and data partitioning proves advantageous in scenarios where the data is geographically dispersed across the United States. Dask enables users to perform filtering tasks concurrently across multiple partitions, facilitating efficient large-scale data processing without the need to load entire datasets into memory at once.
#
# #The conversion of date columns to datetime format benefits significantly from parallel execution, as this process becomes increasingly resource-intensive as the dataset size grows. By leveraging Dask's ability to work on separate data chunks simultaneously, the processing time is accelerated, and memory-related issues that would arise when using Pandas alone are mitigated.
#
# #Parallel processing also demonstrates its compatibility with the operation of filtering dates within a specified range, as it solely requires examining and selecting the applicable rows. Distributed computation allows for the execution of date filters on various partitions concurrently, rather than a linear sequence, resulting in faster processing times.
#
# #The calculation of total deaths per state greatly benefits from parallel execution, as the values can be summed independently per partition. This approach is particularly advantageous when dealing with extensive datasets, as it meets the processing needs efficiently.
#
# #Furthermore, the aggregate operation of calculating the mean per state can be parallelized, as the partial state means are computed in different partitions before being combined. This process not only speeds up the computation but also reduces the memory requirements.
#
# #Overall, the integration of parallel processing and data partitioning through the use of Dask showcases its ability to address the challenges posed by large-scale, geographically dispersed datasets, enabling efficient data processing and analysis without overwhelming system resources.
# The division needed to calculate per-capita death rates can run in parallel because it works on each element . Dask's distributed setup lets the division start after separate calculations for state total deaths and average population finish.
#
# #To figure out monthly case fatality rates, you need to add up both per-month death counts and case totals for each state. Dask can spread these calculations across many cores or computers when dealing with big datasets, as grouping and adding up numbers takes a lot of computing power.
#
# #A distributed system helps manage memory well when working out month-to-month differences. It allows the computation of CFR change for each state. When you have large datasets running the diff operation at the same time across many parts speeds things up
#
# #summary
# #The provided code calculates Case Fatality Rate (CFR) by month for all U.S. states using Dask, a parallel computation platform. The code starts by data filtering by given conditions, and thereafter, performing grouping by to calculate CFR by dividing deaths by total cases by month. The .compute() function is employed to execute computation in parallel, harnessing Dask's ability to effectively handle large datasets. The time-CFR is calculated using the .diff() function to capture month-over-month fatality rate changes. The result is ranked by states by top rate of change, and Connecticut, Michigan, and New Jersey have the top rate of increase. The approach is effective in analyzing massive-scale epidemiological data while keeping memory low.
